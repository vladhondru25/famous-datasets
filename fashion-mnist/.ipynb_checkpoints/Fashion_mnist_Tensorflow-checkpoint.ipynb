# %%
import math
import numpy as np
import tensorflow as tf
import tensorflow.keras.layers as kl
import matplotlib.pyplot as plt

# %%
# Issue. Check https://github.com/dmlc/xgboost/issues/1715
import os
os.environ['KMP_DUPLICATE_LIB_OK']='True'

# %%
# Constants and hyper-parameters
EPOCHS = 15
BATCH_SIZE = 64
VALID_SIZE = 10 #In percentage out of training set
CLASSES = 10
CLASS_NAMES = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat', 'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %%
train_data, (x_test, y_test) = tf.keras.datasets.fashion_mnist.load_data()

split_point = math.floor((100-VALID_SIZE)*len(train_data[0])/100)
x_train, y_train = train_data[0][:split_point], train_data[1][:split_point]
x_valid, y_valid = train_data[0][split_point:], train_data[1][split_point:]

x_train = x_train / 255.0
x_valid = x_valid / 255.0
x_test  = x_test  / 255.0

# Add a channels dimension
x_train = x_train[..., tf.newaxis].astype("float32")
x_valid = x_valid[..., tf.newaxis].astype("float32")
x_test  = x_test[...,  tf.newaxis].astype("float32")

# %%
class FModel(tf.keras.Model):
    def __init__(self):
        super(FModel, self).__init__()
        
        self.network = tf.keras.Sequential([
            kl.Conv2D(filters=6, kernel_size=5, strides=1, padding='same', use_bias=False),
            kl.BatchNormalization(axis=-1),
            kl.Dropout(rate=0.1),
            kl.ReLU(),
            kl.MaxPool2D(pool_size=2, strides=2, padding='valid'),
            
            kl.Conv2D(filters=16, kernel_size=5, strides=1, padding='valid', use_bias=False),
            kl.BatchNormalization(axis=-1),
            kl.Dropout(rate=0.1),
            kl.ReLU(),
            kl.MaxPool2D(pool_size=2, strides=2, padding='valid'),
            
            kl.Flatten(),
            
            kl.Dense(120, activation=None, use_bias=True),
            kl.Dropout(rate=0.1),
            kl.ReLU(),
            
            kl.Dense(84, activation=None, use_bias=True),
            kl.Dropout(rate=0.1),
            kl.ReLU(),
            
            kl.Dense(CLASSES, activation=None, use_bias=True)
        ])
        
    def call(self, x):
        return self.network(x)

# %%
fashionModel = FModel()

loss_function = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)

fashionModel.compile(optimizer='adam', loss=loss_function, metrics=['accuracy'])
# fashionModel.fit(x=x_train, y=y_train, epochs=EPOCHS)#, shuffle=True)
fashionModel.fit(x=x_train, y=y_train, batch_size=BATCH_SIZE, epochs=EPOCHS, verbose=2, validation_data=(x_valid,y_valid), shuffle=True)

plt.figure(0)
plt.plot(list(range(1,EPOCHS+1)), fashionModel.history.history['loss'], 'b')
plt.plot(list(range(1,EPOCHS+1)), fashionModel.history.history['val_loss'], 'r')
plt.xticks(list(range(1,EPOCHS+1)))
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train loss','Validation loss'])
plt.show()
# Out:
# Train on 54000 samples, validate on 6000 samples
# Epoch 1/15
# 54000/54000 - 41s - loss: 0.5169 - accuracy: 0.8138 - val_loss: 0.3584 - val_accuracy: 0.8693
# Epoch 2/15
# 54000/54000 - 41s - loss: 0.3511 - accuracy: 0.8722 - val_loss: 0.3206 - val_accuracy: 0.8827
# Epoch 3/15
# 54000/54000 - 41s - loss: 0.3145 - accuracy: 0.8848 - val_loss: 0.3561 - val_accuracy: 0.8618
# Epoch 4/15
# 54000/54000 - 40s - loss: 0.2897 - accuracy: 0.8938 - val_loss: 0.2861 - val_accuracy: 0.8977
# Epoch 5/15
# 54000/54000 - 40s - loss: 0.2738 - accuracy: 0.8984 - val_loss: 0.2799 - val_accuracy: 0.8962
# Epoch 6/15
# 54000/54000 - 41s - loss: 0.2615 - accuracy: 0.9036 - val_loss: 0.2942 - val_accuracy: 0.8918
# Epoch 7/15
# 54000/54000 - 41s - loss: 0.2472 - accuracy: 0.9082 - val_loss: 0.2567 - val_accuracy: 0.9050
# Epoch 8/15
# 54000/54000 - 41s - loss: 0.2391 - accuracy: 0.9110 - val_loss: 0.2721 - val_accuracy: 0.8980
# Epoch 9/15
# 54000/54000 - 41s - loss: 0.2294 - accuracy: 0.9159 - val_loss: 0.2564 - val_accuracy: 0.9032
# Epoch 10/15
# 54000/54000 - 41s - loss: 0.2250 - accuracy: 0.9155 - val_loss: 0.2731 - val_accuracy: 0.8975
# Epoch 11/15
# 54000/54000 - 41s - loss: 0.2157 - accuracy: 0.9206 - val_loss: 0.2734 - val_accuracy: 0.8988
# Epoch 12/15
# 54000/54000 - 41s - loss: 0.2111 - accuracy: 0.9210 - val_loss: 0.2532 - val_accuracy: 0.9038
# Epoch 13/15
# 54000/54000 - 41s - loss: 0.2034 - accuracy: 0.9240 - val_loss: 0.2585 - val_accuracy: 0.9073
# Epoch 14/15
# 54000/54000 - 41s - loss: 0.1977 - accuracy: 0.9247 - val_loss: 0.2501 - val_accuracy: 0.9047
# Epoch 15/15
# 54000/54000 - 41s - loss: 0.1930 - accuracy: 0.9267 - val_loss: 0.2592 - val_accuracy: 0.9030

# %%
fashionModel.evaluate(x=x_test, y=y_test, batch_size=BATCH_SIZE, verbose=2)
# Out:
# 10000/1 - 3s - loss: 0.2061 - accuracy: 0.9026
# [0.26793813579082487, 0.9026]

# %%
plt.figure(figsize=(15,15))
for i in range(10):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(x_test[i].squeeze(-1), cmap=plt.cm.binary)
    
    logits = fashionModel.predict(x_test[i][np.newaxis,...])
    pred = np.argmax(logits)
    
    plt.xlabel('Predicted: '+CLASS_NAMES[pred]+'\n Actual: '+CLASS_NAMES[y_test[i]])
plt.show()
